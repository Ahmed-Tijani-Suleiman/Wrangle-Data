# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
import pandas as pd
import requests
import numpy as np
import os
import json
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('twitter-archive-enhanced.csv')

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df.text[0]
# Out:
# "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU"

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
#Creating folder using python
folder_name = 'Image_Predictions'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
#Getting the URL
url='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response=requests.get(url)

# %%
#To view the raw data
#response.content

# %%
#Saving the file to the computer
with open(os.path.join(folder_name, url.split('/')[-1]),mode='wb') as file:
        file.write(response.content)

# %%
df_predictions=pd.read_csv('Image_Predictions/image-predictions.tsv', sep='\t')

# %%
df_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
#https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
df_tweet = []
with open('tweet_json.txt') as f:
    for line in f:
        tweet = (json.loads(line))
        tweet_id = tweet['id']
        retweet_count = tweet['retweet_count']
        favorite_count = tweet['favorite_count']
        create_date = tweet['created_at']
        df_tweet.append({'retweet_count' : retweet_count,
                  'favorite_count' : favorite_count,
                  'create_date' : create_date,
                  'tweet_id' : tweet_id})
        
more_data = pd.DataFrame(df_tweet, columns = ['tweet_id', 'retweet_count', 'favorite_count', 'create_date'])

# %%
more_data.head()
# Out:
#              tweet_id  retweet_count  favorite_count  \
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048
#
#                       create_date
# 0  Tue Aug 01 16:23:56 +0000 2017
# 1  Tue Aug 01 00:17:27 +0000 2017
# 2  Mon Jul 31 00:18:03 +0000 2017
# 3  Sun Jul 30 15:58:51 +0000 2017
# 4  Sat Jul 29 16:00:24 +0000 2017

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# ### Visual Accessment

# %%
df
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
# Set the column width in pandas so the full tweet text can be read for analysis
pd.set_option("display.max_colwidth",150)

# %%
df[['source', 'text', 'expanded_urls']]
# Out:
#                                                                                   source  \
# 0     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 5     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 7     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 8     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df_predictions
# Out:
#                 tweet_id  \
# 0     666020888022790149
# 1     666029285002620928
# 2     666033412701032449
# 3     666044226329800704
# 4     666049248165822465
# 5     666050758794694657
# 6     666051853826850816
# 7     666055525042405380
# 8     666057090499244032
# 9     666058600524156928
# 10    666063827256086533
# 11    666071193221509120
# 12    666073100786774016
# 13    666082916733198337
# 14    666094000022159362
# 15    666099513787052032
# 16    666102155909144576
# 17    666104133288665088
# 18    666268910803644416
# 19    666273097616637952
# 20    666287406224695296
# 21    666293911632134144
# 22    666337882303524864
# 23    666345417576210432
# 24    666353288456101888
# 25    666362758909284353
# 26    666373753744588802
# 27    666396247373291520
# 28    666407126856765440
# 29    666411507551481857
# ...                  ...
# 2045  886366144734445568
# 2046  886680336477933568
# 2047  886736880519319552
# 2048  886983233522544640
# ...

# %%
more_data
# Out:
#                 tweet_id  retweet_count  favorite_count  \
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# 5     891087950875897856           3261           20562
# 6     890971913173991426           2158           12041
# 7     890729181411237888          16716           56848
# 8     890609185150312448           4429           28226
# 9     890240255349198849           7711           32467
# 10    890006608113172480           7624           31166
# 11    889880896479866881           5156           28268
# 12    889665388333682689           8538           38818
# 13    889638837579907072           4735           27672
# 14    889531135344209921           2321           15359
# 15    889278841981685760           5637           25652
# ...

# %% [markdown]
# ### Programmatic Accessment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df.name.value_counts()
# Out:
# None         745
# a             55
# Charlie       12
# Lucy          11
# Cooper        11
# Oliver        11
# Penny         10
# Lola          10
# Tucker        10
# Winston        9
# Bo             9
# the            8
# Sadie          8
# Bailey         7
# Buddy          7
# Toby           7
# an             7
# Daisy          7
# Leo            6
# Jack           6
# Dave           6
# Milo           6
# Stanley        6
# Bella          6
# Scout          6
# Rusty          6
# Koda           6
# Jax            6
# Oscar          6
# Gus            5
#             ...
# Stu            1
# Duddles        1
# Tango          1
# Kanu           1
# Skittle        1
# Chadrick       1
# Maya           1
# Sora           1
# Gustav         1
# Kara           1
# Jim            1
# Furzey         1
# Stephanus      1
# Stefan         1
# Dixie          1
# Socks          1
# Mauve          1
# Arlen          1
# Poppy          1
# Sweets         1
# Carbon         1
# ...

# %%
df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_predictions.p1.value_counts()
# Out:
# golden_retriever             150
# Labrador_retriever           100
# Pembroke                      89
# Chihuahua                     83
# pug                           57
# chow                          44
# Samoyed                       43
# toy_poodle                    39
# Pomeranian                    38
# malamute                      30
# cocker_spaniel                30
# French_bulldog                26
# miniature_pinscher            23
# Chesapeake_Bay_retriever      23
# seat_belt                     22
# Siberian_husky                20
# Staffordshire_bullterrier     20
# German_shepherd               20
# web_site                      19
# Cardigan                      19
# Eskimo_dog                    18
# beagle                        18
# Maltese_dog                   18
# teddy                         18
# Shetland_sheepdog             18
# Shih-Tzu                      17
# Lakeland_terrier              17
# Rottweiler                    17
# ...

# %%
df_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
more_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# create_date       2354 non-null object
# dtypes: int64(3), object(1)
# memory usage: 73.6+ KB

# %%
more_data.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %% [markdown]
# ### Quality issues
# 1. Removing retweeted rows. Only original ratings (no retweets/reply) must be considered(as per project requirement).
#
# 2.  Removing rows containing replies from the dataframe
#
# 3. Timestamp column is not in datetime format.
#
# 4. Removing unnecessary columns 'in_reply_to_status_id', 'in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp' from the dataframe.
#
# 5. Change the datatypes for the retweet_count and favorite_count variables from float to int in tweets dataset
#
# 6. Setting descriptive column names.
#
# 7. Setting contents of predicted columns to lower case.
#
# 8. Replace links with html tags in the source column with just the source name.

# %% [markdown]
# ### Tidiness issues
# 1. There are two informations in a single column,the text and the URL.
# 2. The three Data Frames can be merged on the tweet_id

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
df_copy =df.copy()
df_predictions_copy= df_predictions.copy()
more_data_copy =more_data.copy()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df_predictions_copy.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
more_data_copy.head()
# Out:
#              tweet_id  retweet_count  favorite_count  \
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048
#
#                       create_date
# 0  Tue Aug 01 16:23:56 +0000 2017
# 1  Tue Aug 01 00:17:27 +0000 2017
# 2  Mon Jul 31 00:18:03 +0000 2017
# 3  Sun Jul 30 15:58:51 +0000 2017
# 4  Sat Jul 29 16:00:24 +0000 2017

# %% [markdown]
# ### Tidiness.

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define: Removing the url from the text column using regex.

# %% [markdown]
# #### Code

# %%
df_copy[['tweet_id', 'text']].sample(5)
# Out:
#                 tweet_id  \
# 178   857263160327368704
# 885   760153949710192640
# 2243  667902449697558528
# 470   816816676327063552
# 655   791784077045166082
#
#                                                                                                                                                        text
# 178   This is Oscar and Oliver. Oliver shrunk Oscar. Oscar isn't pleased about it. Quite pupset tbh. Oliver doesn't seem to mind. Both 13/10 https://t.c...
# 885                          RT @hownottodraw: The story/person behind @dog_rates is heckin adorable af. 11/10, probably would pet. https://t.co/AG5UnRrmzJ
# 2243              This is Cleopatricia. She is a northern Paperback Maple. Set up hammock somehow. 9/10 would chill in hammock with https://t.co/sJeHdGUt0W
# 470                                     This is Timber. He misses Christmas. Specifically the presents part. 12/10 cheer pup Timber https://t.co/dVVavqpeF9
# ...

# %%
df_copy['text'] = df.text.apply(lambda x : re.sub('http\S+','', x).strip())

# %% [markdown]
# #### Test

# %%
df_copy[['tweet_id', 'text']].sample(10)
# Out:
#                 tweet_id  \
# 1560  688519176466644993
# 2102  670679630144274432
# 691   787322443945877504
# 1813  676776431406465024
# 1789  677547928504967168
# 1011  747439450712596480
# 1055  742385895052087300
# 1591  686606069955735556
# 1107  734776360183431168
# 1763  678446151570427904
#
#                                                                                                                          text
# 1560                                                This pupper is sprouting a flower out of her head. 12/10 revolutionary af
# 2102      This is Pluto. He's holding little waddling dog hostage. Little waddling dog very desperate at this point sos. 8/10
# 691                 This is Lincoln. He forgot to use his blinker when he changed lanes just now. Guilty as h*ck. Still 10/10
# 1813                            When someone yells "cops!" at a party and you gotta get your drunk friend out of there. 10/10
# ...

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define: merge all three dataframes on tweet_id

# %% [markdown]
# #### Code

# %%
df_copy.shape
# Out:
# (2356, 17)

# %%
df_copy.tweet_id = df_copy.tweet_id.astype('str') #convert tweet_id from int to str
more_data_copy.tweet_id = more_data_copy.tweet_id.astype('str') #convert tweet_id from int to str
df_predictions_copy.tweet_id=df_predictions_copy.tweet_id.astype('str')

# %%
df_copy = pd.merge(df_copy, more_data_copy,
                on=['tweet_id'], how='inner')

# %%
df_copy = pd.merge(df_copy,df_predictions_copy,
                on=['tweet_id'], how='inner')

# %% [markdown]
# #### Test

# %%
df_copy.sample()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1835  670433248821026816                    NaN                  NaN
#
#                       timestamp  \
# 1835  2015-11-28 02:45:17 +0000
#
#                                                                                   source  \
# 1835  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                         text  \
# 1835  This is Sam. He's trying to escape the inordinate monotony of conforming to everyday status quo. 10/10
#
#       retweeted_status_id  retweeted_status_user_id  \
# 1835                  NaN                       NaN
#
#      retweeted_status_timestamp  \
# 1835                        NaN
#
#                                                         expanded_urls  ...    \
# 1835  https://twitter.com/dog_rates/status/670433248821026816/photo/1  ...
#
# ...

# %%
df_copy.shape
# Out:
# (2073, 31)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2073 entries, 0 to 2072
# Data columns (total 31 columns):
# tweet_id                      2073 non-null object
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2073 non-null object
# source                        2073 non-null object
# text                          2073 non-null object
# retweeted_status_id           79 non-null float64
# retweeted_status_user_id      79 non-null float64
# retweeted_status_timestamp    79 non-null object
# expanded_urls                 2073 non-null object
# rating_numerator              2073 non-null int64
# rating_denominator            2073 non-null int64
# name                          2073 non-null object
# doggo                         2073 non-null object
# floofer                       2073 non-null object
# pupper                        2073 non-null object
# ...

# %% [markdown]
# ### Data Quality

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define: Removing retweeted rows from the dataframe.

# %%
df_copy.shape
# Out:
# (2073, 31)

# %% [markdown]
# #### Code

# %%
#view the dataframe columns
df_copy.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'retweet_count', 'favorite_count', 'create_date', 'jpg_url', 'img_num',
#        'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf',
#        'p3_dog'],
#       dtype='object')

# %%
#removing rows where retweet status is not null
df_copy=df_copy[df_copy.retweeted_status_id.isnull()]

# %% [markdown]
# #### Test

# %%
df_copy.retweeted_status_id.value_counts()
# Out:
# Series([], Name: retweeted_status_id, dtype: int64)

# %%
df_copy.shape
# Out:
# (1994, 31)

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define:  Removing rows with replies present from the dataframe.

# %% [markdown]
# #### Code

# %%
#removing rows where reply status is not null
df_copy= df_copy[df_copy.in_reply_to_status_id.isnull()]

# %% [markdown]
# #### Test

# %%
df_copy.shape
# Out:
# (1971, 31)

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Define: converting timestamp in df_copy dataframe to datetime.

# %% [markdown]
# #### Code

# %%
df_copy.timestamp=pd.to_datetime(df_copy.timestamp);

# %% [markdown]
# #### Test

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2072
# Data columns (total 31 columns):
# tweet_id                      1971 non-null object
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     1971 non-null datetime64[ns]
# source                        1971 non-null object
# text                          1971 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1971 non-null object
# rating_numerator              1971 non-null int64
# rating_denominator            1971 non-null int64
# name                          1971 non-null object
# doggo                         1971 non-null object
# floofer                       1971 non-null object
# pupper                        1971 non-null object
# ...

# %% [markdown]
# ### Issue #4:

# %% [markdown]
# #### Define: Remove unnecessary columns from df_copy

# %% [markdown]
# #### Code

# %%
df_copy.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'retweet_count', 'favorite_count', 'create_date', 'jpg_url', 'img_num',
#        'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf',
#        'p3_dog'],
#       dtype='object')

# %%
df_copy.drop(['in_reply_to_status_id', 'in_reply_to_user_id','retweeted_status_id', 'retweeted_status_user_id',
       'retweeted_status_timestamp'],axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
df_copy.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo', 'retweet_count', 'favorite_count', 'create_date',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
df_copy.sample()
# Out:
#                tweet_id           timestamp  \
# 475  799297110730567681 2016-11-17 17:04:16
#
#                                                                                  source  \
# 475  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                             text  \
# 475  This is Jeffrey. He's quite the jokester. Takes it too far sometimes. Still 11/10 would pet
#
#                                                                                                                        expanded_urls  \
# 475  https://twitter.com/dog_rates/status/799297110730567681/photo/1,https://twitter.com/dog_rates/status/799297110730567681/photo/1
#
#      rating_numerator  rating_denominator     name doggo floofer   ...    \
# 475                11                  10  Jeffrey  None    None   ...
#
#     img_num        p1   p1_conf  p1_dog              p2   p2_conf  p2_dog  \
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2072
# Data columns (total 26 columns):
# tweet_id              1971 non-null object
# timestamp             1971 non-null datetime64[ns]
# source                1971 non-null object
# text                  1971 non-null object
# expanded_urls         1971 non-null object
# rating_numerator      1971 non-null int64
# rating_denominator    1971 non-null int64
# name                  1971 non-null object
# doggo                 1971 non-null object
# floofer               1971 non-null object
# pupper                1971 non-null object
# puppo                 1971 non-null object
# retweet_count         1971 non-null int64
# favorite_count        1971 non-null int64
# create_date           1971 non-null object
# jpg_url               1971 non-null object
# img_num               1971 non-null int64
# p1                    1971 non-null object
# p1_conf               1971 non-null float64
# ...

# %% [markdown]
# ### Issue #5:

# %% [markdown]
# #### Define: Change the datatypes for the retweet_count and favorite_count column from float to int.

# %% [markdown]
# #### Code

# %%
df_copy[['retweet_count', 'favorite_count']]=df_copy[['retweet_count', 'favorite_count']].astype(int)

# %% [markdown]
# #### Test

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2072
# Data columns (total 26 columns):
# tweet_id              1971 non-null object
# timestamp             1971 non-null datetime64[ns]
# source                1971 non-null object
# text                  1971 non-null object
# expanded_urls         1971 non-null object
# rating_numerator      1971 non-null int64
# rating_denominator    1971 non-null int64
# name                  1971 non-null object
# doggo                 1971 non-null object
# floofer               1971 non-null object
# pupper                1971 non-null object
# puppo                 1971 non-null object
# retweet_count         1971 non-null int64
# favorite_count        1971 non-null int64
# create_date           1971 non-null object
# jpg_url               1971 non-null object
# img_num               1971 non-null int64
# p1                    1971 non-null object
# p1_conf               1971 non-null float64
# ...

# %% [markdown]
# ### Issue #6:

# %% [markdown]
# #### Define: Setting Descriptive name Columns.

# %% [markdown]
# #### Code

# %%
df_copy.rename(columns={'p1': 'prediction_1', 'p2':'prediction_2', 'p3':'prediction_3', 'p1_conf':'confidence_value_1', 'p2_conf':'confidence_value_2', 'p3_conf':'confidence_value_3','p1_dog':'result_1', 'p2_dog':'result_2', 'p3_dog':'result_3'}, inplace=True);

# %% [markdown]
# #### Test

# %%
df_copy.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo', 'retweet_count', 'favorite_count', 'create_date',
#        'jpg_url', 'img_num', 'prediction_1', 'confidence_value_1', 'result_1',
#        'prediction_2', 'confidence_value_2', 'result_2', 'prediction_3',
#        'confidence_value_3', 'result_3'],
#       dtype='object')

# %% [markdown]
# ### Issue #7:

# %% [markdown]
# #### Define: Set contents of predicted columns to lower case.

# %% [markdown]
# #### Code

# %%
df_copy['prediction_1'] = df_copy['prediction_1'].str.lower()
df_copy['prediction_2'] = df_copy['prediction_2'].str.lower()
df_copy['prediction_3'] = df_copy['prediction_3'].str.lower()

# %% [markdown]
# #### Test

# %%
df_copy.prediction_1
# Out:
# 0                            orange
# 1                         chihuahua
# 2                         chihuahua
# 3                       paper_towel
# 4                            basset
# 5          chesapeake_bay_retriever
# 6                       appenzeller
# 7                        pomeranian
# 8                     irish_terrier
# 9                          pembroke
# 10                          samoyed
# 11                   french_bulldog
# 12                         pembroke
# 13                   french_bulldog
# 14                 golden_retriever
# 15                          whippet
# 16                 golden_retriever
# 17                 golden_retriever
# 18                   siberian_husky
# 19                   french_bulldog
# 20                           basset
# 21                        limousine
# 22                         pembroke
# 23                 mexican_hairless
# 24                          samoyed
# 25                        chihuahua
# ...

# %% [markdown]
# ### Issue #8:

# %% [markdown]
# #### Define: Replace link with html tag with source name using regex.

# %%
df_copy.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     1932
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       28
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
df_copy.source = df_copy.source.str.extract('^<a.+>(.+)</a>$')

# %%
df_copy.source.value_counts()
# Out:
# Twitter for iPhone    1932
# Twitter Web Client      28
# TweetDeck               11
# Name: source, dtype: int64

# %%
df_copy.duplicated().any()
# Out:
# False

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
df_copy.to_csv("twitter_archive_master.csv", index=False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
df= pd.read_csv("twitter_archive_master.csv")

# %%
df.head()
# Out:
#              tweet_id            timestamp              source  \
# 0  892420643555336193  2017-08-01 16:23:56  Twitter for iPhone
# 1  892177421306343426  2017-08-01 00:17:27  Twitter for iPhone
# 2  891815181378084864  2017-07-31 00:18:03  Twitter for iPhone
# 3  891689557279858688  2017-07-30 15:58:51  Twitter for iPhone
# 4  891327558926688256  2017-07-29 16:00:24  Twitter for iPhone
#
#                                                                                                                                          text  \
# 0                                                       This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10
# 1  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10
# 2                   This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10
# ...

# %%
df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo', 'retweet_count', 'favorite_count', 'create_date',
#        'jpg_url', 'img_num', 'prediction_1', 'confidence_value_1', 'result_1',
#        'prediction_2', 'confidence_value_2', 'result_2', 'prediction_3',
#        'confidence_value_3', 'result_3'],
#       dtype='object')

# %% [markdown]
# ### Insights:
# #### 1. Most used source of dog rating data.

# %%
df.source.value_counts()
# Out:
# Twitter for iPhone    1932
# Twitter Web Client      28
# TweetDeck               11
# Name: source, dtype: int64

# %% [markdown]
# #### 2. Relationship between retweet and favorite count.

# %%
df[['retweet_count','favorite_count']].corr()
# Out:
#                 retweet_count  favorite_count
# retweet_count        1.000000        0.913014
# favorite_count       0.913014        1.000000

# %% [markdown]
# #### 3. Top 10 most liked dogs.

# %%
top_ten= df[['name','favorite_count',
       'jpg_url', 'prediction_1', 'confidence_value_1', 'result_1',
       'prediction_2', 'confidence_value_2', 'result_2', 'prediction_3',
       'confidence_value_3', 'result_3']].nlargest(5, 'favorite_count')
top_ten
# Out:
#         name  favorite_count  \
# 306     None          132810
# 769     None          131075
# 58   Duddles          107956
# 397  Stephan          107015
# 108   Jamesy          106827
#
#                                                                                      jpg_url  \
# 306                                          https://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg
# 769  https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg
# 58   https://pbs.twimg.com/ext_tw_video_thumb/879415784908390401/pu/img/cX7XI1TnUsseGET5.jpg
# 397  https://pbs.twimg.com/ext_tw_video_thumb/807106774843039744/pu/img/8XZg1xW35Xp2J6JW.jpg
# 108                                          https://pbs.twimg.com/media/DAZAUfBXcAAG_Nn.jpg
#
#            prediction_1  confidence_value_1  result_1        prediction_2  \
# 306    lakeland_terrier            0.196015      True  labrador_retriever
# 769  labrador_retriever            0.825333      True            ice_bear
# ...

# %% [markdown]
# #### We select the prediction 1 column for our visualization because it has the highest confidence value.

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='prediction_1', y='favorite_count', data=top_ten, color='r')
plt.xlabel('Dog_Name');

# %% [markdown]
# ### Visualization
# The Visualization below shows the relation ship between Retweets and Favorite Count.

# %%
plt.figure(figsize=(13,7))
sns.regplot(x=df.retweet_count, y=df.favorite_count)
plt.title("Favorites and Retweets")
plt.xlabel('Retweets')
plt.ylabel('Favorites');
